# %% [markdown]
# # Example Notebook
#
# This is a template notebook demonstrating the project setup.

# %%
# Import the project module
import src

print(f"Project version: {src.__version__}")

# %%
# Example code cell
data = [1, 2, 3, 4, 5]
squared = [x**2 for x in data]
print(f"Original: {data}")
print(f"Squared: {squared}")
